# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

dates = pd.date_range(start='2023-01-01', periods=1000, freq='H')
data = np.random.rand(1000, 2) * 100
df_dummy = pd.DataFrame(data, index=dates, columns=['Feature1', 'Feature2'])
df_dummy.index.name = 'Timestamp'
df_dummy.iloc[50:150, 0] = np.nan
df_dummy.iloc[200:300, 1] = np.nan
df_dummy.to_csv('time_series_data.csv')

df = pd.read_csv('time_series_data.csv', index_col=0, parse_dates=True)
df.fillna(method='ffill', inplace=True)
print("Data head:\n", df.head())

target_col = 'Feature1'
window = 10
values = df[[target_col]].values.astype('float32')

scaler = MinMaxScaler()
values_scaled = scaler.fit_transform(values)

X, y = [], []
for i in range(window, len(values_scaled)):
    X.append(values_scaled[i-window:i, 0])
    y.append(values_scaled[i, 0])
X = np.array(X)
y = np.array(y)

X = X.reshape((X.shape[0], X.shape[1], 1))

train_size = int(0.8 * len(X))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")

model = models.Sequential([
    layers.LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True),
    layers.LSTM(30),
    layers.Dense(1)
])
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()

history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=1)

y_pred_scaled = model.predict(X_test)
y_test_actual = scaler.inverse_transform(y_test.reshape(-1,1))
y_pred_actual = scaler.inverse_transform(y_pred_scaled)

rmse = np.sqrt(mean_squared_error(y_test_actual, y_pred_actual))
mae = mean_absolute_error(y_test_actual, y_pred_actual)
r2 = r2_score(y_test_actual, y_pred_actual)

print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"R-squared (R2) Score: {r2:.4f}")
# Out:
# /tmp/ipython-input-927371917.py:8: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   dates = pd.date_range(start='2023-01-01', periods=1000, freq='H')
# /tmp/ipython-input-927371917.py:17: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Data head:
#                        Feature1   Feature2
# Timestamp
# 2023-01-01 00:00:00  78.009455  33.891859
# 2023-01-01 01:00:00  38.746181  47.257566
# 2023-01-01 02:00:00  57.422555  89.251781
# 2023-01-01 03:00:00  24.199878  27.257694
# 2023-01-01 04:00:00  92.324953  81.964427
# X_train shape: (792, 10, 1), y_train shape: (792,)
# X_test shape: (198, 10, 1), y_test shape: (198,)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 10, 50)         │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 30)             │         9,720 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            31 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,151 (78.71 KB)
#  Trainable params: 20,151 (78.71 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.1794 - mae: 0.3507 - val_loss: 0.0833 - val_mae: 0.2428
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0804 - mae: 0.2423 - val_loss: 0.0827 - val_mae: 0.2439
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0754 - mae: 0.2327 - val_loss: 0.0820 - val_mae: 0.2429
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0773 - mae: 0.2333 - val_loss: 0.0815 - val_mae: 0.2423
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0810 - mae: 0.2437 - val_loss: 0.0857 - val_mae: 0.2481
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0799 - mae: 0.2353 - val_loss: 0.0817 - val_mae: 0.2429
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0749 - mae: 0.2309 - val_loss: 0.0813 - val_mae: 0.2425
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0785 - mae: 0.2394 - val_loss: 0.0815 - val_mae: 0.2416
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0822 - mae: 0.2453 - val_loss: 0.0808 - val_mae: 0.2418
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0771 - mae: 0.2384 - val_loss: 0.0815 - val_mae: 0.2429
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0784 - mae: 0.2394 - val_loss: 0.0836 - val_mae: 0.2456
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0778 - mae: 0.2366 - val_loss: 0.0837 - val_mae: 0.2458
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0784 - mae: 0.2390 - val_loss: 0.0838 - val_mae: 0.2458
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0792 - mae: 0.2411 - val_loss: 0.0810 - val_mae: 0.2425
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0772 - mae: 0.2393 - val_loss: 0.0814 - val_mae: 0.2428
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0757 - mae: 0.2335 - val_loss: 0.0805 - val_mae: 0.2417
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0762 - mae: 0.2391 - val_loss: 0.0826 - val_mae: 0.2445
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0781 - mae: 0.2408 - val_loss: 0.0858 - val_mae: 0.2482
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0727 - mae: 0.2291 - val_loss: 0.0815 - val_mae: 0.2430
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0808 - mae: 0.2476 - val_loss: 0.0816 - val_mae: 0.2431
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0747 - mae: 0.2322 - val_loss: 0.0805 - val_mae: 0.2418
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0757 - mae: 0.2325 - val_loss: 0.0814 - val_mae: 0.2429
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0810 - mae: 0.2419 - val_loss: 0.0829 - val_mae: 0.2449
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0809 - mae: 0.2422 - val_loss: 0.0854 - val_mae: 0.2477
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0723 - mae: 0.2258 - val_loss: 0.0819 - val_mae: 0.2437
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0811 - mae: 0.2421 - val_loss: 0.0805 - val_mae: 0.2419
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0755 - mae: 0.2360 - val_loss: 0.0841 - val_mae: 0.2461
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0779 - mae: 0.2373 - val_loss: 0.0850 - val_mae: 0.2473
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0767 - mae: 0.2372 - val_loss: 0.0806 - val_mae: 0.2419
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0766 - mae: 0.2386 - val_loss: 0.0810 - val_mae: 0.2425
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0731 - mae: 0.2313 - val_loss: 0.0804 - val_mae: 0.2417
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0758 - mae: 0.2354 - val_loss: 0.0807 - val_mae: 0.2422
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0759 - mae: 0.2382 - val_loss: 0.0806 - val_mae: 0.2420
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0762 - mae: 0.2390 - val_loss: 0.0806 - val_mae: 0.2419
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0768 - mae: 0.2379 - val_loss: 0.0803 - val_mae: 0.2415
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0769 - mae: 0.2366 - val_loss: 0.0802 - val_mae: 0.2413
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0779 - mae: 0.2423 - val_loss: 0.0812 - val_mae: 0.2427
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0794 - mae: 0.2427 - val_loss: 0.0817 - val_mae: 0.2433
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0793 - mae: 0.2422 - val_loss: 0.0805 - val_mae: 0.2419
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0797 - mae: 0.2451 - val_loss: 0.0822 - val_mae: 0.2440
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0738 - mae: 0.2301 - val_loss: 0.0801 - val_mae: 0.2411
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0790 - mae: 0.2428 - val_loss: 0.0825 - val_mae: 0.2444
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0793 - mae: 0.2398 - val_loss: 0.0831 - val_mae: 0.2450
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0782 - mae: 0.2378 - val_loss: 0.0817 - val_mae: 0.2434
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0741 - mae: 0.2330 - val_loss: 0.0801 - val_mae: 0.2411
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0777 - mae: 0.2395 - val_loss: 0.0815 - val_mae: 0.2431
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0781 - mae: 0.2391 - val_loss: 0.0815 - val_mae: 0.2431
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0767 - mae: 0.2351 - val_loss: 0.0818 - val_mae: 0.2435
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0821 - mae: 0.2469 - val_loss: 0.0803 - val_mae: 0.2415
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0799 - mae: 0.2486 - val_loss: 0.0822 - val_mae: 0.2442
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7bcf235f9c60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Root Mean Squared Error (RMSE): 28.6198
# Mean Absolute Error (MAE): 24.3697
# R-squared (R2) Score: -0.0358
